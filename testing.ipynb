# %%
from datasets import load_from_disk

data = load_from_disk('pickles/merged_dataset/arabic_portuguese')

for i in range(10):
    print(data[i]['sentence'])
# Out:
# نحن لسنا أمريكيين. Não é minha casa.
# من هناك؟ Foi aqui?
# أنا متأكد أني أستطيع أن أفعل هذا بطريقة أو بأخري. Isso definitivamente funciona bem.
# كم الساعة؟ Quanto você quer?
# لقد فعلت ذلك لأجلها. ela decidiu contra isso.
# ألا يوجد قطعة أرضٍ هنا للبيع؟ Muitos lugares vendem chá por aqui?
# هل أنتِ سعيدة في منزلك ؟ Como decorar seu lar para a primavera
# لست متزوجا. Eu não posso ser uma boa filha.
# أنا قلت شيئا. Eu estava lá.
# هل لديكن موعد؟ Podemos falar amanhã?

# %%
import IPython.display as ipd

ipd.Audio(data=data[0]["audio"], autoplay=True, rate=48000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
ipd.Audio(data=data[1]["audio"], autoplay=True, rate=48000)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
